# %%
from tools.lib.logreader import LogReader
from tools.lib.route import Route
import os
import random
# routes = ["650b1e4383a9baf2|2021-06-13--15-57-56", "650b1e4383a9baf2|2021-06-13--13-47-57", "650b1e4383a9baf2|2021-06-13--12-43-28"]
route_name = "47067b3ff5652692|2021-08-21--13-48-13"
route = Route(route_name)
log_paths = route.log_paths()

# ld = os.listdir("/home/gregor/route/separate2/")
# route_name = "2021-07-31--14-46-10"
# import re

# def tryint(s):
#     try:
#         return int(s)
#     except:
#         return s

# def alphanum_key(s):
#     """ Turn a string into a list of string and number chunks.
#         "z23a" -> ["z", 23, "a"]
#     """
#     return [ tryint(c) for c in re.split('([0-9]+)', s) ]
# ld.sort(key=alphanum_key)
# log_paths =["/home/gregor/route/separate2/"+x+"/rlog.bz2" for x in ld]


print(str(log_paths).replace(",","\n"))
# Out:
# ['/home/gregor/route/separate2/2021-07-31--14-46-10--0/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--1/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--2/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--3/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--4/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--5/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--6/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--7/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--8/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--9/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--10/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--11/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--12/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--13/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--14/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--15/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--16/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--17/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--18/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--19/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--20/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--21/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--22/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--23/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--24/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--25/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--26/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--27/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--28/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--29/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--30/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--31/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--32/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--33/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--34/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--35/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--36/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--37/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--38/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--39/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--40/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--41/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--42/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--43/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--44/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--45/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--46/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--47/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--48/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--49/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--50/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--51/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--52/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--53/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--54/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--55/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--56/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--57/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--58/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--59/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--60/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--61/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--62/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--63/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--64/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--65/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--66/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--67/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--68/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--69/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--70/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--71/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--72/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--73/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--74/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--75/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--76/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--77/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--78/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--79/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--80/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--81/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--82/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--83/rlog.bz2'
#  '/home/gregor/route/separate2/2021-07-31--14-46-10--84/rlog.bz2']

# %%
events_seg0 = list(LogReader(log_paths[0]))
print(len(events_seg0), 'events logged in first segment')
# Out:
# 67620 events logged in first segment

# %%
options = set()
for e in events_seg0:
    parsed = e.to_dict()
    for x in parsed:
        options.add(x)

for x in options:
    print(x)
# Out:
# logMessage
# sentinel
# controlsState
# driverMonitoringState
# gpsLocationExternal
# ubloxRaw
# clocks
# thumbnail
# modelV2
# sendcan
# longitudinalPlan
# pandaState
# carControl
# carEvents
# lateralPlan
# ubloxGnss
# liveCalibration
# driverState
# liveLocationKalman
# initData
# procLog
# liveParameters
# driverCameraState
# cameraOdometry
# valid
# roadCameraState
# carParams
# radarState
# androidLog
# sensorEvents
# liveTracks
# managerState
# carState
# deviceState
# can
# roadEncodeIdx
# logMonoTime

# %%
from tqdm import tqdm
carState = []
controlsState = []
sensorEvents = []
d = [True]*3

for path in log_paths:
    events_seg = list(LogReader(path))
#     print(len(events_seg), 'events logged in segment')
    for e in tqdm(events_seg):
        lenOk = max(len(carState), len(controlsState))
        if e.which() not in ["carState", "controlsState", "sensorEvents"]:
            continue
        parsed = e.to_dict()
        for x in parsed:
            if x =="carState":
                carState.append(parsed)
                if d[0]:
                    print(parsed)
                    d[0]=False
            if x =="controlsState":
                controlsState.append(parsed)
                if d[1]:
                    print(parsed)
                    d[1]=False
            if x=="sensorEvents":
                sensorEvents.append(parsed)
                if d[2]:
                    print(parsed)
                    d[2]=False
# Out:
#  11%|█▏        | 7700/67620 [00:00<00:01, 51283.33it/s]
# {'sensorEvents': [{'gyroUncalibrated': {'v': [-0.025665283203125, 0.0427398681640625, 0.0574188232421875, -0.02740478515625, 0.0410919189453125, 0.05615234375], 'status': 0}, 'version': 104, 'sensor': 5, 'type': 16, 'timestamp': 2212187312801, 'source': 'android', 'uncalibratedDEPRECATED': False}], 'logMonoTime': 2212194755040, 'valid': True}
# {'controlsState': {'vEgoDEPRECATED': 0.0, 'aEgoDEPRECATED': 0.0, 'vPid': 0.30000001192092896, 'vTargetLead': 0.0, 'upAccelCmd': 0.0, 'uiAccelCmd': 0.0, 'yActualDEPRECATED': 0.0, 'yDesDEPRECATED': 0.0, 'upSteerDEPRECATED': 0.0, 'uiSteerDEPRECATED': 0.0, 'aTargetMinDEPRECATED': 0.0, 'aTargetMaxDEPRECATED': 0.0, 'jerkFactorDEPRECATED': 0.0, 'angleSteersDEPRECATED': 0.0, 'hudLeadDEPRECATED': 0, 'cumLagMs': -0.0, 'canMonoTimeDEPRECATED': 0, 'radarStateMonoTimeDEPRECATED': 0, 'mdMonoTimeDEPRECATED': 0, 'enabled': False, 'steerOverrideDEPRECATED': False, 'canMonoTimes': [], 'vCruise': 255.0, 'rearViewCamDEPRECATED': False, 'alertText1': 'WARNING: This branch is not tested', 'alertText2': 'Always keep hands on wheel and eyes on road', 'awarenessStatusDEPRECATED': 0.0, 'angleModelBiasDEPRECATED': 0.0, 'longitudinalPlanMonoTime': 0, 'steeringAngleDesiredDegDEPRECATED': 0.0, 'longControlState': 'off', 'state': 'disabled', 'vEgoRawDEPRECATED': 0.0, 'ufAccelCmd': 0.0, 'ufSteerDEPRECATED': 0.0, 'aTarget': 0.0, 'active': False, 'curvature': 0.15091192722320557, 'alertStatus': 'userPrompt', 'alertSize': 'mid', 'gpsPlannerActiveDEPRECATED': False, 'engageable': False, 'alertBlinkingRate': 0.0, 'driverMonitoringOnDEPRECATED': False, 'alertType': 'startupMaster/permanent', 'vCurvatureDEPRECATED': 0.0, 'decelForTurnDEPRECATED': False, 'startMonoTime': 2212377714571, 'mapValidDEPRECATED': False, 'lateralPlanMonoTime': 0, 'forceDecel': False, 'lateralControlState': {'pidState': {'active': False, 'steeringAngleDeg': -2.299999952316284, 'steeringRateDeg': 0.0, 'angleError': 0.0, 'p': 0.0, 'i': 0.0, 'f': 0.0, 'output': 0.0, 'saturated': False}}, 'decelForModelDEPRECATED': False, 'alertSound': 'none', 'canErrorCounter': 0}, 'logMonoTime': 2212386883061, 'valid': False}
# {'carState': {'vEgo': 0.0, 'wheelSpeeds': {'fl': 0.0, 'fr': 0.0, 'rl': 0.0, 'rr': 0.0}, 'gas': 0.0, 'gasPressed': False, 'brake': 0.40625, 'brakePressed': True, 'steeringAngleDeg': -2.299999952316284, 'steeringTorque': 123.0, 'steeringPressed': False, 'cruiseState': {'enabled': False, 'speed': 0.0, 'available': False, 'speedOffset': 0.0, 'standstill': False, 'nonAdaptive': False}, 'buttonEvents': [], 'events': [{'name': 'doorOpen', 'enable': False, 'noEntry': True, 'warning': False, 'userDisable': False, 'softDisable': True, 'immediateDisable': False, 'preEnable': False, 'permanent': False}, {'name': 'seatbeltNotLatched', 'enable': False, 'noEntry': True, 'warning': False, 'userDisable': False, 'softDisable': True, 'immediateDisable': False, 'preEnable': False, 'permanent': False}, {'name': 'silentWrongGear', 'enable': False, 'noEntry': True, 'warning': False, 'userDisable': False, 'softDisable': True, 'immediateDisable': False, 'preEnable': False, 'permanent': False}, {'name': 'wrongCarMode', 'enable': False, 'noEntry': True, 'warning': False, 'userDisable': True, 'softDisable': False, 'immediateDisable': False, 'preEnable': False, 'permanent': False}, {'name': 'espDisabled', 'enable': False, 'noEntry': True, 'warning': False, 'userDisable': False, 'softDisable': True, 'immediateDisable': False, 'preEnable': False, 'permanent': False}, {'name': 'silentPedalPressed', 'enable': False, 'noEntry': True, 'warning': False, 'userDisable': True, 'softDisable': False, 'immediateDisable': False, 'preEnable': False, 'permanent': False}, {'name': 'parkBrake', 'enable': False, 'noEntry': True, 'warning': False, 'userDisable': True, 'softDisable': False, 'immediateDisable': False, 'preEnable': False, 'permanent': False}, {'name': 'startupMaster', 'enable': False, 'noEntry': False, 'warning': False, 'userDisable': False, 'softDisable': False, 'immediateDisable': False, 'preEnable': False, 'permanent': True}, {'name': 'controlsInitializing', 'enable': False, 'noEntry': True, 'warning': False, 'userDisable': False, 'softDisable': False, 'immediateDisable': False, 'preEnable': False, 'permanent': False}], 'gearShifter': 'park', 'steeringRateDeg': 0.0, 'aEgo': 0.0, 'vEgoRaw': 0.0, 'standstill': True, 'brakeLightsDEPRECATED': False, 'leftBlinker': False, 'rightBlinker': False, 'yawRate': -0.0, 'genericToggle': False, 'doorOpen': True, 'seatbeltUnlatched': True, 'canValid': False, 'steeringTorqueEps': 0.0, 'clutchPressed': False, 'steeringRateLimited': False, 'stockAeb': False, 'stockFcw': False, 'espDisabled': True, 'leftBlindspot': False, 'rightBlindspot': False, 'steerWarning': False, 'steerError': False, 'lkasEnabled': False, 'leftBlinkerOn': False, 'rightBlinkerOn': False, 'disengageByBrake': False, 'automaticLaneChange': True, 'belowLaneChangeSpeed': True, 'accEnabled': False}, 'logMonoTime': 2212387984154, 'valid': False}
# 100%|██████████| 67620/67620 [00:02<00:00, 28986.97it/s]
# 100%|██████████| 60225/60225 [00:02<00:00, 28172.99it/s]
# 100%|██████████| 60203/60203 [00:02<00:00, 29089.65it/s]
# 100%|██████████| 60167/60167 [00:02<00:00, 28835.18it/s]
# 100%|██████████| 58986/58986 [00:02<00:00, 27246.00it/s]
# 100%|██████████| 59506/59506 [00:02<00:00, 27242.60it/s]
# 100%|██████████| 59810/59810 [00:02<00:00, 25871.56it/s]
# 100%|██████████| 59940/59940 [00:02<00:00, 25086.67it/s]
# 100%|██████████| 59446/59446 [00:02<00:00, 23540.39it/s]
# 100%|██████████| 59980/59980 [00:01<00:00, 33287.94it/s]
# 100%|██████████| 59480/59480 [00:01<00:00, 32782.27it/s]
# 100%|██████████| 59929/59929 [00:02<00:00, 21907.99it/s]
# 100%|██████████| 59890/59890 [00:01<00:00, 34409.90it/s]
# 100%|██████████| 59290/59290 [00:02<00:00, 21013.19it/s]
# 100%|██████████| 60213/60213 [00:01<00:00, 32959.45it/s]
# 100%|██████████| 59267/59267 [00:02<00:00, 19998.89it/s]
# 100%|██████████| 59792/59792 [00:01<00:00, 34505.67it/s]
# 100%|██████████| 59852/59852 [00:03<00:00, 19422.35it/s]
# 100%|██████████| 59329/59329 [00:01<00:00, 34185.02it/s]
# 100%|██████████| 59084/59084 [00:01<00:00, 34196.51it/s]
# 100%|██████████| 59394/59394 [00:01<00:00, 31330.36it/s]
# 100%|██████████| 59021/59021 [00:01<00:00, 34250.05it/s]
# 100%|██████████| 59376/59376 [00:01<00:00, 34648.95it/s]
# 100%|██████████| 59419/59419 [00:01<00:00, 33693.61it/s]
# 100%|██████████| 58959/58959 [00:01<00:00, 34567.86it/s]
# 100%|██████████| 59366/59366 [00:01<00:00, 34103.17it/s]
# 100%|██████████| 58659/58659 [00:03<00:00, 15527.35it/s]
# 100%|██████████| 59643/59643 [00:01<00:00, 34032.81it/s]
# 100%|██████████| 62158/62158 [00:01<00:00, 35998.73it/s]
# 100%|██████████| 59515/59515 [00:01<00:00, 34156.46it/s]
# 100%|██████████| 59449/59449 [00:01<00:00, 33896.64it/s]
# 100%|██████████| 59158/59158 [00:01<00:00, 34653.69it/s]
# 100%|██████████| 59624/59624 [00:01<00:00, 34670.70it/s]
# 100%|██████████| 59122/59122 [00:01<00:00, 34516.05it/s]
# 100%|██████████| 59255/59255 [00:01<00:00, 33569.94it/s]
# 100%|██████████| 59196/59196 [00:01<00:00, 34204.57it/s]
# 100%|██████████| 58992/58992 [00:01<00:00, 33671.97it/s]
# 100%|██████████| 59062/59062 [00:01<00:00, 33641.64it/s]
# 100%|██████████| 59425/59425 [00:04<00:00, 12700.43it/s]
# 100%|██████████| 59095/59095 [00:01<00:00, 33217.89it/s]
# 100%|██████████| 59507/59507 [00:01<00:00, 32843.86it/s]
# 100%|██████████| 59483/59483 [00:01<00:00, 34035.99it/s]
# 100%|██████████| 59709/59709 [00:01<00:00, 34296.43it/s]
# 100%|██████████| 59292/59292 [00:05<00:00, 11660.09it/s]
# 100%|██████████| 59750/59750 [00:01<00:00, 33556.99it/s]
# 100%|██████████| 59523/59523 [00:01<00:00, 34410.37it/s]
# 100%|██████████| 59612/59612 [00:01<00:00, 34353.93it/s]
# 100%|██████████| 59730/59730 [00:01<00:00, 33406.36it/s]
# 100%|██████████| 60002/60002 [00:01<00:00, 33588.60it/s]
# 100%|██████████| 59423/59423 [00:01<00:00, 33708.42it/s]
# 100%|██████████| 59699/59699 [00:01<00:00, 33595.34it/s]
# 100%|██████████| 59562/59562 [00:01<00:00, 34085.73it/s]
# 100%|██████████| 59273/59273 [00:01<00:00, 34200.38it/s]
# 100%|██████████| 59869/59869 [00:01<00:00, 33596.54it/s]
# 100%|██████████| 59695/59695 [00:01<00:00, 33427.66it/s]
# 100%|██████████| 59758/59758 [00:01<00:00, 32862.12it/s]
# 100%|██████████| 59359/59359 [00:01<00:00, 32008.22it/s]
# 100%|██████████| 59306/59306 [00:01<00:00, 33097.63it/s]
# 100%|██████████| 59453/59453 [00:01<00:00, 32735.29it/s]
# 100%|██████████| 59518/59518 [00:01<00:00, 33541.96it/s]
# 100%|██████████| 59862/59862 [00:01<00:00, 31954.39it/s]
# 100%|██████████| 59494/59494 [00:01<00:00, 30428.53it/s]
# 100%|██████████| 59605/59605 [00:06<00:00, 9075.22it/s]
# 100%|██████████| 59742/59742 [00:01<00:00, 33192.48it/s]
# 100%|██████████| 59865/59865 [00:01<00:00, 34171.03it/s]
# 100%|██████████| 59926/59926 [00:01<00:00, 34409.36it/s]
# 100%|██████████| 59771/59771 [00:01<00:00, 33990.20it/s]
# 100%|██████████| 59869/59869 [00:01<00:00, 32909.27it/s]
# 100%|██████████| 60017/60017 [00:01<00:00, 32646.49it/s]
# 100%|██████████| 59948/59948 [00:01<00:00, 34417.29it/s]
# 100%|██████████| 59836/59836 [00:01<00:00, 32625.26it/s]
# 100%|██████████| 59633/59633 [00:01<00:00, 34154.64it/s]
# 100%|██████████| 65399/65399 [00:01<00:00, 37602.78it/s]
# 100%|██████████| 59689/59689 [00:01<00:00, 33769.21it/s]
# 100%|██████████| 59854/59854 [00:01<00:00, 34343.43it/s]
# 100%|██████████| 59547/59547 [00:01<00:00, 32089.11it/s]
# 100%|██████████| 59566/59566 [00:01<00:00, 33593.67it/s]
# 100%|██████████| 59573/59573 [00:01<00:00, 33932.97it/s]
# 100%|██████████| 59867/59867 [00:01<00:00, 33992.92it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-b075389931ef> in <module>
#       6
#       7 for path in log_paths:
# ----> 8     events_seg = list(LogReader(path))
#       9 #     print(len(events_seg), 'events logged in segment')
#      10     for e in tqdm(events_seg):
#
# ~/openpilot/tools/lib/logreader.py in __init__(self, fn, canonicalize, only_union_types)
#      87       ents = capnp_log.Event.read_multiple_bytes(dat)
#      88     elif ext == ".bz2":
# ---> 89       dat = bz2.decompress(dat)
#      90       ents = capnp_log.Event.read_multiple_bytes(dat)
#      91     else:
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/bz2.py in decompress(data)
#     348         decomp = BZ2Decompressor()
#     349         try:
# --> 350             res = decomp.decompress(data)
#     351         except OSError:
#     352             if results:
#
# KeyboardInterrupt:

# %%
acc = []
t_acc = []
alpha = []
t_alpha = []

t_sensor = []
t_CS = []

print(len(carState), len(controlsState), len(sensorEvents))
for i in (range(len(sensorEvents))):
    sensor = sensorEvents[i]
    time = sensor["logMonoTime"]
#     print(time)
    t_sensor.append(time)
    se = sensor["sensorEvents"] #Array of sensor outputs at some time
    for x in se:
        if "acceleration" in x:
            acc.append(x["acceleration"]["v"])
            t_acc.append(time)
        if "gyro" in x:
            alpha.append(x["gyro"]["v"])
            t_alpha.append(time)


for i in (range(len(carState))):
    CS = carState[i]
    time = CS["logMonoTime"]
    t_CS.append(time)

print(len(acc), len(alpha))
# Out:
# 467549 467549 988535
# 502831 502841

# %%
print(len(t_sensor), len(t_CS))
t_CS+=[t_CS[-1]]*(len(t_sensor)-len(t_CS)) #Padding
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams["figure.figsize"] = (20,12)

plt.plot(np.linspace(0, len(t_sensor), len(t_sensor)), t_sensor)
plt.plot(np.linspace(0, len(t_sensor), len(t_sensor)), t_CS)
# Out:
# 988535 467549

# %%
angle = []
speed = []
torque_output = []
driver_torque = []

#Need sync
imu_v = []
imu_alpha = []

p_cars = 0
p_acc = 0
p_alpha = 0
for i in range(len(carState)-2):
    CS = carState[i]
    controls = controlsState[i]
    timeCS = CS["logMonoTime"]
#     print(timeCS, controls["logMonoTime"])
    while t_acc[p_acc] < timeCS:
        p_acc+=1
    while t_alpha[p_alpha] < timeCS:
        p_alpha+=1
    
    #CS, controls, sensors are matched
#     print(timeCS, controls["logMonoTime"], t_acc[p_acc], t_alpha[p_alpha])
    step = CS["carState"]
    angle.append(step["steeringAngleDeg"])
    speed.append(step["vEgo"])
    driver_torque.append(step["steeringTorque"])
    
    step = controls["controlsState"]
    torque_output.append(step["lateralControlState"]["pidState"]["output"])
    
    imu_v.append(acc[p_acc])
    imu_alpha.append(alpha[p_alpha])
#     print(step)
#     break

# %%
_, axs = plt.subplots(4)
time = len(carState)-2
axs[0].plot(np.linspace(0, time, time), speed)
axs[1].plot(np.linspace(0, time, time), angle)
axs[2].plot(np.linspace(0, time, time), driver_torque)
axs[3].plot(np.linspace(0, time, time), [imu_v[i][0] for i in range(len(imu_v))])

# %%
goodOutputs = []
time = len(angle)
curr = []

sm = 0#Sum of time

dt = 0
for i in range(time):
    if dt>0:
        dt-=1
        continue
    ok = True
    if speed[i]<20:
        ok = False
    if abs(driver_torque[i]) > 1200:
        ok = False
        dt = 100
    if len(curr) > 60*100:
        ok = False
    if ok:
        curr.append([i, angle[i], speed[i], torque_output[i], imu_v[i][0], imu_v[i][1], imu_v[i][2], imu_alpha[i][0], imu_alpha[i][1], imu_alpha[i][2]])
    else:
        if len(curr) > 20 * 100:
            goodOutputs.append(curr)
            print(i-len(curr), i, len(curr)//100)
            sm += len(curr)//100
        curr = []
print(sm)
# Out:
# 84366 86800 24
# 89921 95922 60
# 99562 101755 21
# 107851 113796 59
# 114242 120243 60
# 120244 124958 47
# 125463 128320 28
# 129077 135078 60
# 135079 140381 53
# 140826 144145 33
# 146583 148637 20
# 174770 177910 31
# 187537 193538 60
# 193539 199540 60
# 200580 206581 60
# 208287 214083 57
# 221152 227153 60
# 227154 233155 60
# 233156 239157 60
# 243282 248254 49
# 248658 253526 48
# 279848 282352 25
# 286526 291869 53
# 295334 301335 60
# 301336 304907 35
# 340413 344675 42
# 362038 366243 42
# 396316 399395 30
# 445786 451787 60
# 457928 460923 29
# 1386

# %%
import numpy as np
#Format:
# index, angle, speed, torque, IMU(speed_dot, angle_dot)*6
for i, output in enumerate(goodOutputs):
    np.savetxt(f"train_exports/{route_name}-{i}.csv", output, delimiter =" ", fmt ='% s')
