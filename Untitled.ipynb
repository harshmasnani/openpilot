# %%
from tools.lib.logreader import LogReader
from tools.lib.route import Route
import os
import random
# routes = ["650b1e4383a9baf2|2021-06-13--15-57-56", "650b1e4383a9baf2|2021-06-13--13-47-57", "650b1e4383a9baf2|2021-06-13--12-43-28"]
# route_name = "f280907e439de88d|2021-08-02--21-37-42"
# route = Route(route_name)
ld = os.listdir("/home/gregor/route/separate/")
import re

def tryint(s):
    try:
        return int(s)
    except:
        return s

def alphanum_key(s):
    """ Turn a string into a list of string and number chunks.
        "z23a" -> ["z", 23, "a"]
    """
    return [ tryint(c) for c in re.split('([0-9]+)', s) ]
ld.sort(key=alphanum_key)
log_paths =["/home/gregor/route/separate/"+x+"/rlog.bz2" for x in ld]


print(str(log_paths).replace(",","\n"))
# Out:
# ['/home/gregor/route/separate/2021-07-31--23-54-21--0/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--1/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--2/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--3/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--4/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--5/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--6/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--7/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--8/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--9/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--10/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--11/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--12/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--13/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--14/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--15/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--16/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--17/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--18/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--19/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--20/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--21/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--22/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--23/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--24/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--25/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--26/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--27/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--28/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--29/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--30/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--31/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--32/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--33/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--34/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--35/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--36/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--37/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--38/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--39/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--40/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--41/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--42/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--43/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--44/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--45/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--46/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--47/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--48/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--49/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--50/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--51/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--52/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--53/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--54/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--55/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--56/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--57/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--58/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--59/rlog.bz2'
#  '/home/gregor/route/separate/2021-07-31--23-54-21--60/rlog.bz2']

# %%
events_seg0 = list(LogReader(log_paths[0]))
print(len(events_seg0), 'events logged in first segment')
# Out:
# 69630 events logged in first segment

# %%
options = set()
for e in events_seg0:
    parsed = e.to_dict()
    for x in parsed:
        options.add(x)

for x in options:
    print(x)
# Out:
# carEvents
# longitudinalPlan
# deviceState
# ubloxGnss
# androidLog
# controlsState
# can
# clocks
# driverCameraState
# cameraOdometry
# roadCameraState
# logMonoTime
# procLog
# sentinel
# logMessage
# modelV2
# lateralPlan
# managerState
# sendcan
# radarState
# liveParameters
# pandaState
# liveLocationKalman
# carControl
# carParams
# carState
# ubloxRaw
# liveTracks
# gpsLocationExternal
# roadEncodeIdx
# valid
# initData
# thumbnail
# driverMonitoringState
# sensorEvents
# liveCalibration
# driverState

# %%
from tqdm import tqdm
carState = []
controlsState = []
sensorEvents = []
d = [True]*3

for path in log_paths:
    events_seg = list(LogReader(path))
#     print(len(events_seg), 'events logged in segment')
    for e in tqdm(events_seg):
        lenOk = max(len(carState), len(controlsState))
        if e.which() not in ["carState", "controlsState", "sensorEvents"]:
            continue
        parsed = e.to_dict()
        for x in parsed:
            if x =="carState":
                carState.append(parsed)
                if d[0]:
                    print(parsed)
                    d[0]=False
            if x =="controlsState":
                controlsState.append(parsed)
                if d[1]:
                    print(parsed)
                    d[1]=False
            if x=="sensorEvents":
                sensorEvents.append(parsed)
                if d[2]:
                    print(parsed)
                    d[2]=False
# Out:
#  14%|█▍        | 10018/69630 [00:00<00:00, 100112.79it/s]
# {'sensorEvents': [{'acceleration': {'v': [9.91119384765625, 0.0939483642578125, -0.02099609375], 'status': 3}, 'version': 104, 'sensor': 1, 'type': 1, 'timestamp': 9638449447468, 'source': 'android', 'uncalibratedDEPRECATED': False}, {'gyro': {'v': [-0.0018768310546875, -0.0004119873046875, -0.00177001953125], 'status': 3}, 'version': 104, 'sensor': 4, 'type': 4, 'timestamp': 9638449447468, 'source': 'android', 'uncalibratedDEPRECATED': False}, {'gyroUncalibrated': {'v': [-0.0244293212890625, 0.0305328369140625, 0.0574188232421875, -0.022552490234375, 0.03094482421875, 0.0591888427734375], 'status': 0}, 'version': 104, 'sensor': 5, 'type': 16, 'timestamp': 9638449447468, 'source': 'android', 'uncalibratedDEPRECATED': False}], 'logMonoTime': 9638450919707, 'valid': True}
# {'controlsState': {'vEgoDEPRECATED': 0.0, 'aEgoDEPRECATED': 0.0, 'vPid': 0.30000001192092896, 'vTargetLead': 0.0, 'upAccelCmd': 0.0, 'uiAccelCmd': 0.0, 'yActualDEPRECATED': 0.0, 'yDesDEPRECATED': 0.0, 'upSteerDEPRECATED': 0.0, 'uiSteerDEPRECATED': 0.0, 'aTargetMinDEPRECATED': 0.0, 'aTargetMaxDEPRECATED': 0.0, 'jerkFactorDEPRECATED': 0.0, 'angleSteersDEPRECATED': 0.0, 'hudLeadDEPRECATED': 0, 'cumLagMs': -0.0, 'canMonoTimeDEPRECATED': 0, 'radarStateMonoTimeDEPRECATED': 0, 'mdMonoTimeDEPRECATED': 0, 'enabled': False, 'steerOverrideDEPRECATED': False, 'canMonoTimes': [], 'vCruise': 255.0, 'rearViewCamDEPRECATED': False, 'alertText1': 'WARNING: This branch is not tested', 'alertText2': 'Always keep hands on wheel and eyes on road', 'awarenessStatusDEPRECATED': 0.0, 'angleModelBiasDEPRECATED': 0.0, 'longitudinalPlanMonoTime': 0, 'steeringAngleDesiredDegDEPRECATED': 0.0, 'longControlState': 'off', 'state': 'disabled', 'vEgoRawDEPRECATED': 0.0, 'ufAccelCmd': 0.0, 'ufSteerDEPRECATED': 0.0, 'aTarget': 0.0, 'active': False, 'curvature': 0.1443505436182022, 'alertStatus': 'userPrompt', 'alertSize': 'mid', 'gpsPlannerActiveDEPRECATED': False, 'engageable': False, 'alertBlinkingRate': 0.0, 'driverMonitoringOnDEPRECATED': False, 'alertType': 'startupMaster/permanent', 'vCurvatureDEPRECATED': 0.0, 'decelForTurnDEPRECATED': False, 'startMonoTime': 9638525095957, 'mapValidDEPRECATED': False, 'lateralPlanMonoTime': 0, 'forceDecel': False, 'lateralControlState': {'pidState': {'active': False, 'steeringAngleDeg': -2.200000047683716, 'steeringRateDeg': 0.0, 'angleError': 0.0, 'p': 0.0, 'i': 0.0, 'f': 0.0, 'output': 0.0, 'saturated': False}}, 'decelForModelDEPRECATED': False, 'alertSound': 'none', 'canErrorCounter': 0}, 'logMonoTime': 9638533269551, 'valid': False}
# {'carState': {'vEgo': 0.0, 'wheelSpeeds': {'fl': 0.0, 'fr': 0.0, 'rl': 0.0, 'rr': 0.0}, 'gas': 0.0, 'gasPressed': False, 'brake': 2.515625, 'brakePressed': True, 'steeringAngleDeg': -2.200000047683716, 'steeringTorque': 191.0, 'steeringPressed': False, 'cruiseState': {'enabled': False, 'speed': 0.0, 'available': False, 'speedOffset': 0.0, 'standstill': False, 'nonAdaptive': False}, 'buttonEvents': [], 'events': [{'name': 'doorOpen', 'enable': False, 'noEntry': True, 'warning': False, 'userDisable': False, 'softDisable': True, 'immediateDisable': False, 'preEnable': False, 'permanent': False}, {'name': 'seatbeltNotLatched', 'enable': False, 'noEntry': True, 'warning': False, 'userDisable': False, 'softDisable': True, 'immediateDisable': False, 'preEnable': False, 'permanent': False}, {'name': 'silentWrongGear', 'enable': False, 'noEntry': True, 'warning': False, 'userDisable': False, 'softDisable': True, 'immediateDisable': False, 'preEnable': False, 'permanent': False}, {'name': 'wrongCarMode', 'enable': False, 'noEntry': True, 'warning': False, 'userDisable': True, 'softDisable': False, 'immediateDisable': False, 'preEnable': False, 'permanent': False}, {'name': 'espDisabled', 'enable': False, 'noEntry': True, 'warning': False, 'userDisable': False, 'softDisable': True, 'immediateDisable': False, 'preEnable': False, 'permanent': False}, {'name': 'silentPedalPressed', 'enable': False, 'noEntry': True, 'warning': False, 'userDisable': True, 'softDisable': False, 'immediateDisable': False, 'preEnable': False, 'permanent': False}, {'name': 'parkBrake', 'enable': False, 'noEntry': True, 'warning': False, 'userDisable': True, 'softDisable': False, 'immediateDisable': False, 'preEnable': False, 'permanent': False}, {'name': 'startupMaster', 'enable': False, 'noEntry': False, 'warning': False, 'userDisable': False, 'softDisable': False, 'immediateDisable': False, 'preEnable': False, 'permanent': True}, {'name': 'controlsInitializing', 'enable': False, 'noEntry': True, 'warning': False, 'userDisable': False, 'softDisable': False, 'immediateDisable': False, 'preEnable': False, 'permanent': False}], 'gearShifter': 'park', 'steeringRateDeg': 0.0, 'aEgo': 0.0, 'vEgoRaw': 0.0, 'standstill': True, 'brakeLightsDEPRECATED': False, 'leftBlinker': False, 'rightBlinker': False, 'yawRate': -0.0, 'genericToggle': False, 'doorOpen': True, 'seatbeltUnlatched': True, 'canValid': False, 'steeringTorqueEps': 0.0, 'clutchPressed': False, 'steeringRateLimited': False, 'stockAeb': False, 'stockFcw': False, 'espDisabled': True, 'leftBlindspot': False, 'rightBlindspot': False, 'steerWarning': False, 'steerError': False, 'lkasEnabled': False, 'leftBlinkerOn': False, 'rightBlinkerOn': False, 'disengageByBrake': False, 'automaticLaneChange': True, 'belowLaneChangeSpeed': True, 'accEnabled': False}, 'logMonoTime': 9638534394030, 'valid': False}
# 100%|██████████| 69630/69630 [00:01<00:00, 39014.29it/s]
# 100%|██████████| 60080/60080 [00:01<00:00, 35167.65it/s]
# 100%|██████████| 60154/60154 [00:03<00:00, 17712.83it/s]
# 100%|██████████| 59635/59635 [00:01<00:00, 34120.38it/s]
# 100%|██████████| 59743/59743 [00:01<00:00, 32886.58it/s]
# 100%|██████████| 59613/59613 [00:01<00:00, 32510.70it/s]
# 100%|██████████| 59666/59666 [00:01<00:00, 33913.07it/s]
# 100%|██████████| 59639/59639 [00:01<00:00, 34486.43it/s]
# 100%|██████████| 59451/59451 [00:01<00:00, 33973.00it/s]
# 100%|██████████| 59504/59504 [00:01<00:00, 33870.23it/s]
# 100%|██████████| 59388/59388 [00:01<00:00, 33056.44it/s]
# 100%|██████████| 59323/59323 [00:01<00:00, 33829.56it/s]
# 100%|██████████| 59393/59393 [00:03<00:00, 15156.38it/s]
# 100%|██████████| 59384/59384 [00:01<00:00, 33024.51it/s]
# 100%|██████████| 59733/59733 [00:01<00:00, 33669.10it/s]
# 100%|██████████| 59605/59605 [00:04<00:00, 13453.20it/s]
# 100%|██████████| 59459/59459 [00:01<00:00, 32844.32it/s]
# 100%|██████████| 59784/59784 [00:01<00:00, 34076.00it/s]
# 100%|██████████| 59230/59230 [00:04<00:00, 13306.76it/s]
# 100%|██████████| 59563/59563 [00:01<00:00, 35614.52it/s]
# 100%|██████████| 59461/59461 [00:01<00:00, 36634.24it/s]
# 100%|██████████| 59524/59524 [00:04<00:00, 12250.08it/s]
# 100%|██████████| 59541/59541 [00:01<00:00, 35696.82it/s]
# 100%|██████████| 59643/59643 [00:01<00:00, 34272.79it/s]
# 100%|██████████| 59668/59668 [00:01<00:00, 34367.04it/s]
# 100%|██████████| 59546/59546 [00:05<00:00, 11799.06it/s]
# 100%|██████████| 59786/59786 [00:01<00:00, 35045.16it/s]
# 100%|██████████| 59557/59557 [00:01<00:00, 33725.17it/s]
# 100%|██████████| 59746/59746 [00:01<00:00, 34306.90it/s]
# 100%|██████████| 59588/59588 [00:05<00:00, 10816.93it/s]
# 100%|██████████| 59645/59645 [00:01<00:00, 34369.25it/s]
# 100%|██████████| 59751/59751 [00:01<00:00, 34085.65it/s]
# 100%|██████████| 59819/59819 [00:01<00:00, 33413.21it/s]
# 100%|██████████| 59679/59679 [00:01<00:00, 33697.40it/s]
# 100%|██████████| 59592/59592 [00:06<00:00, 9799.40it/s]
# 100%|██████████| 59662/59662 [00:01<00:00, 33297.50it/s]
# 100%|██████████| 59711/59711 [00:01<00:00, 33403.83it/s]
# 100%|██████████| 59536/59536 [00:01<00:00, 32742.20it/s]
# 100%|██████████| 59624/59624 [00:01<00:00, 32406.67it/s]
# 100%|██████████| 59659/59659 [00:01<00:00, 35376.55it/s]
# 100%|██████████| 59724/59724 [00:01<00:00, 34880.81it/s]
# 100%|██████████| 59796/59796 [00:01<00:00, 33131.85it/s]
# 100%|██████████| 59714/59714 [00:01<00:00, 34140.23it/s]
# 100%|██████████| 59611/59611 [00:01<00:00, 34063.00it/s]
# 100%|██████████| 59870/59870 [00:01<00:00, 32163.59it/s]
# 100%|██████████| 59863/59863 [00:01<00:00, 33082.55it/s]
# 100%|██████████| 59729/59729 [00:01<00:00, 33200.93it/s]
# 100%|██████████| 59767/59767 [00:01<00:00, 34256.93it/s]
# 100%|██████████| 59580/59580 [00:01<00:00, 33694.54it/s]
# 100%|██████████| 59646/59646 [00:01<00:00, 33650.44it/s]
# 100%|██████████| 59591/59591 [00:01<00:00, 34885.40it/s]
# 100%|██████████| 59720/59720 [00:01<00:00, 35502.13it/s]
# 100%|██████████| 59564/59564 [00:07<00:00, 8213.40it/s]
# 100%|██████████| 59654/59654 [00:01<00:00, 35251.82it/s]
# 100%|██████████| 59899/59899 [00:01<00:00, 34209.92it/s]
# 100%|██████████| 59798/59798 [00:01<00:00, 32231.69it/s]
# 100%|██████████| 59617/59617 [00:01<00:00, 34717.28it/s]
# 100%|██████████| 59786/59786 [00:01<00:00, 34009.00it/s]
# 100%|██████████| 59817/59817 [00:01<00:00, 33036.71it/s]
# 100%|██████████| 59880/59880 [00:01<00:00, 32667.80it/s]
# 100%|██████████| 24566/24566 [00:07<00:00, 3502.06it/s]

# %%
acc = []
t_acc = []
alpha = []
t_alpha = []

t_sensor = []
t_CS = []

print(len(carState), len(controlsState), len(sensorEvents))
for i in (range(len(sensorEvents))):
    sensor = sensorEvents[i]
    time = sensor["logMonoTime"]
#     print(time)
    t_sensor.append(time)
    se = sensor["sensorEvents"] #Array of sensor outputs at some time
    for x in se:
        if "acceleration" in x:
            acc.append(x["acceleration"]["v"])
            t_acc.append(time)
        if "gyro" in x:
            alpha.append(x["gyro"]["v"])
            t_alpha.append(time)


for i in (range(len(carState))):
    CS = carState[i]
    time = CS["logMonoTime"]
    t_CS.append(time)

print(len(acc), len(alpha))
# Out:
# 361906 361906 746589
# 384599 384599

# %%
print(len(t_sensor), len(t_CS))
t_CS+=[t_CS[-1]]*(len(t_sensor)-len(t_CS)) #Padding
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams["figure.figsize"] = (20,12)

plt.plot(np.linspace(0, len(t_sensor), len(t_sensor)), t_sensor)
plt.plot(np.linspace(0, len(t_sensor), len(t_sensor)), t_CS)
# Out:
# 746589 361906

# %%
angle = []
speed = []
torque_output = []
driver_torque = []

#Need sync
imu_v = []
imu_alpha = []

p_cars = 0
p_acc = 0
p_alpha = 0
for i in range(len(carState)-1):
    CS = carState[i]
    controls = controlsState[i]
    timeCS = CS["logMonoTime"]
#     print(timeCS, controls["logMonoTime"])
    while t_acc[p_acc] < timeCS:
        p_acc+=1
    while t_alpha[p_alpha] < timeCS:
        p_alpha+=1
    
    #CS, controls, sensors are matched
#     print(timeCS, controls["logMonoTime"], t_acc[p_acc], t_alpha[p_alpha])
    step = CS["carState"]
    angle.append(step["steeringAngleDeg"])
    speed.append(step["vEgo"])
    driver_torque.append(step["steeringTorque"])
    
    step = controls["controlsState"]
    torque_output.append(step["lateralControlState"]["pidState"]["output"])
    
    imu_v.append(acc[p_acc])
    imu_alpha.append(alpha[p_alpha])
#     print(step)
#     break

# %%
_, axs = plt.subplots(4)
time = len(carState)-1
axs[0].plot(np.linspace(0, time, time), speed)
axs[1].plot(np.linspace(0, time, time), angle)
axs[2].plot(np.linspace(0, time, time), driver_torque)
axs[3].plot(np.linspace(0, time, time), [imu_v[i][0] for i in range(len(imu_v))])

# %%
goodOutputs = []
time = len(angle)
curr = []
sm = 0
for i in range(time):
    ok = True
    if speed[i]<20:
        ok = False
    if abs(driver_torque[i]) > 1200:
        ok = False
    if ok:
        curr.append([i, angle[i], speed[i], torque_output[i], imu_v[i][0], imu_v[i][1], imu_v[i][2], imu_alpha[i][0], imu_alpha[i][1], imu_alpha[i][2]])
    if not ok:
        if len(curr) > 20 * 100:
            goodOutputs.append(curr)
            print(i-len(curr), i, len(curr)//100)
            sm += len(curr)//100
        curr = []
print(sm)
# Out:
# 33761 39356 55
# 39389 65486 260
# 65651 72464 68
# 73607 78762 51
# 79749 85725 59
# 86041 91996 59
# 131371 134156 27
# 134652 139862 52
# 142065 149748 76
# 152550 154875 23
# 155036 157203 21
# 160532 163370 28
# 163848 168557 47
# 173859 180036 61
# 180047 183920 38
# 183963 190484 65
# 193654 203080 94
# 203105 213002 98
# 215228 240690 254
# 242644 247604 49
# 248676 251286 26
# 252499 261416 89
# 278661 286455 77
# 287394 306561 191
# 306578 309041 24
# 309068 313185 41
# 313214 320526 73
# 322486 326428 39
# 326447 331616 51
# 333723 338634 49
# 339581 344867 52
# 2197

# %%
import numpy as np
#Format:
# index, angle, speed, torque, IMU(speed_dot, angle_dot)*6
for i, output in enumerate(goodOutputs):
    np.savetxt(f"train_exports/{route_name}-{i}.csv", output, delimiter =" ", fmt ='% s')
