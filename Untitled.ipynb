# %%
from tools.lib.logreader import LogReader
from tools.lib.route import Route
import os
import random
routes = ["650b1e4383a9baf2|2021-06-13--15-57-56", "650b1e4383a9baf2|2021-06-13--13-47-57", "650b1e4383a9baf2|2021-06-13--12-43-28"]
route_name = routes[2]
route = Route(route_name)
log_paths = route.log_paths()
# print(str(log_paths).replace(",","\n"))

# %%
events_seg0 = list(LogReader(log_paths[0]))
print(len(events_seg0), 'events logged in first segment')
# Out:
# 56301 events logged in first segment

# %%
options = set()
for e in events_seg0:
    parsed = e.to_dict()
    for x in parsed:
        options.add(x)

for x in options:
    print(x)
# Out:
# logMessage
# pandaState
# sentinel
# sensorEvents
# driverCameraState
# liveTracks
# roadEncodeIdx
# liveCalibration
# roadCameraState
# procLog
# liveParameters
# driverState
# radarState
# modelV2
# logMonoTime
# gpsLocationExternal
# driverEncodeIdx
# liveLocationKalman
# sendcan
# can
# ubloxGnss
# ubloxRaw
# deviceState
# clocks
# carState
# cameraOdometry
# valid
# driverMonitoringState
# controlsState
# androidLog
# carParams
# lateralPlan
# managerState
# carEvents
# thumbnail
# longitudinalPlan
# carControl
# initData

# %%
from tqdm import tqdm
carState = []
controlsState = []
sensorEvents = []
d = [True]*3

for path in log_paths:
    events_seg = list(LogReader(path))
#     print(len(events_seg), 'events logged in segment')
    for e in tqdm(events_seg):
        lenOk = max(len(carState), len(controlsState))
        if e.which() not in ["carState", "controlsState", "sensorEvents"]:
            continue
        parsed = e.to_dict()
        for x in parsed:
            if x =="carState":
                carState.append(parsed)
                if d[0]:
                    print(parsed)
                    d[0]=False
            if x =="controlsState":
                controlsState.append(parsed)
                if d[1]:
                    print(parsed)
                    d[1]=False
            if x=="sensorEvents":
                sensorEvents.append(parsed)
                if d[2]:
                    print(parsed)
                    d[2]=False
# Out:
#   5%|▌         | 2836/56301 [00:00<00:01, 28327.74it/s]{'sensorEvents': [{'acceleration': {'v': [8.853561401367188, -0.0400543212890625, 0.82366943359375], 'status': 3}, 'version': 104, 'sensor': 1, 'type': 1, 'timestamp': 99662824668, 'source': 'android', 'uncalibratedDEPRECATED': False}, {'gyro': {'v': [0.0049591064453125, 0.0048675537109375, -0.010528564453125], 'status': 3}, 'version': 104, 'sensor': 4, 'type': 4, 'timestamp': 99662824668, 'source': 'android', 'uncalibratedDEPRECATED': False}], 'logMonoTime': 99663687512, 'valid': True}
# {'controlsState': {'vEgoDEPRECATED': 0.0, 'aEgoDEPRECATED': 0.0, 'vPid': 16.156944274902344, 'vTargetLead': 0.0, 'upAccelCmd': 0.0, 'uiAccelCmd': 0.0, 'yActualDEPRECATED': 0.0, 'yDesDEPRECATED': 0.0, 'upSteerDEPRECATED': 0.0, 'uiSteerDEPRECATED': 0.0, 'aTargetMinDEPRECATED': 0.0, 'aTargetMaxDEPRECATED': 0.0, 'jerkFactorDEPRECATED': 0.0, 'angleSteersDEPRECATED': 0.0, 'hudLeadDEPRECATED': 0, 'cumLagMs': 0.0, 'canMonoTimeDEPRECATED': 0, 'radarStateMonoTimeDEPRECATED': 0, 'mdMonoTimeDEPRECATED': 0, 'enabled': False, 'steerOverrideDEPRECATED': False, 'canMonoTimes': [], 'vCruise': 255.0, 'rearViewCamDEPRECATED': False, 'alertText1': 'WARNING: This branch is not tested', 'alertText2': 'Always keep hands on wheel and eyes on road', 'awarenessStatusDEPRECATED': 0.0, 'angleModelBiasDEPRECATED': 0.0, 'longitudinalPlanMonoTime': 0, 'steeringAngleDesiredDegDEPRECATED': 0.0, 'longControlState': 'off', 'state': 'disabled', 'vEgoRawDEPRECATED': 0.0, 'ufAccelCmd': 0.0, 'ufSteerDEPRECATED': 0.0, 'aTarget': 0.0, 'active': False, 'curvature': 0.3596358895301819, 'alertStatus': 'userPrompt', 'alertSize': 'mid', 'gpsPlannerActiveDEPRECATED': False, 'engageable': False, 'alertBlinkingRate': 0.0, 'driverMonitoringOnDEPRECATED': False, 'alertType': 'startupMaster/permanent', 'vCurvatureDEPRECATED': 0.0, 'decelForTurnDEPRECATED': False, 'startMonoTime': 103628757666, 'mapValidDEPRECATED': False, 'lateralPlanMonoTime': 0, 'forceDecel': False, 'lateralControlState': {'pidState': {'active': False, 'steeringAngleDeg': -16.799999237060547, 'steeringRateDeg': -4.462500095367432, 'angleError': 0.0, 'p': 0.0, 'i': 0.0, 'f': 0.0, 'output': 0.0, 'saturated': False, 'd': 0.0}}, 'decelForModelDEPRECATED': False, 'alertSound': 'none', 'canErrorCounter': 0}, 'logMonoTime': 103639563083, 'valid': True}
# {'carState': {'vEgo': 16.156944274902344, 'wheelSpeeds': {'fl': 16.16666603088379, 'fr': 16.21388816833496, 'rl': 16.186111450195312, 'rr': 16.061111450195312}, 'gas': 1.0, 'gasPressed': True, 'brake': 0.0012000000569969416, 'brakePressed': False, 'steeringAngleDeg': -16.799999237060547, 'steeringTorque': -136.0, 'steeringPressed': True, 'cruiseState': {'enabled': False, 'speed': 0.0, 'available': False, 'speedOffset': 0.0, 'standstill': False, 'nonAdaptive': False}, 'buttonEvents': [], 'events': [{'name': 'espDisabled', 'enable': False, 'noEntry': True, 'warning': False, 'userDisable': False, 'softDisable': True, 'immediateDisable': False, 'preEnable': False, 'permanent': False}, {'name': 'gasPressed', 'enable': False, 'noEntry': False, 'warning': False, 'userDisable': False, 'softDisable': False, 'immediateDisable': False, 'preEnable': True, 'permanent': False}, {'name': 'pedalPressed', 'enable': False, 'noEntry': True, 'warning': False, 'userDisable': True, 'softDisable': False, 'immediateDisable': False, 'preEnable': False, 'permanent': False}, {'name': 'pcmDisable', 'enable': False, 'noEntry': False, 'warning': False, 'userDisable': True, 'softDisable': False, 'immediateDisable': False, 'preEnable': False, 'permanent': False}, {'name': 'steerTempUnavailable', 'enable': False, 'noEntry': True, 'warning': False, 'userDisable': False, 'softDisable': True, 'immediateDisable': False, 'preEnable': False, 'permanent': False}, {'name': 'startupMaster', 'enable': False, 'noEntry': False, 'warning': False, 'userDisable': False, 'softDisable': False, 'immediateDisable': False, 'preEnable': False, 'permanent': True}, {'name': 'commIssue', 'enable': False, 'noEntry': True, 'warning': False, 'userDisable': False, 'softDisable': True, 'immediateDisable': False, 'preEnable': False, 'permanent': False}, {'name': 'plannerError', 'enable': False, 'noEntry': True, 'warning': False, 'userDisable': False, 'softDisable': False, 'immediateDisable': True, 'preEnable': False, 'permanent': False}], 'gearShifter': 'drive', 'steeringRateDeg': -4.462500095367432, 'aEgo': 0.0, 'vEgoRaw': 16.156944274902344, 'standstill': False, 'brakeLightsDEPRECATED': False, 'leftBlinker': False, 'rightBlinker': False, 'yawRate': -0.06754424422979355, 'genericToggle': False, 'doorOpen': False, 'seatbeltUnlatched': False, 'canValid': True, 'steeringTorqueEps': 0.0, 'clutchPressed': False, 'steeringRateLimited': False, 'stockAeb': False, 'stockFcw': False, 'espDisabled': True, 'leftBlindspot': False, 'rightBlindspot': False, 'steerWarning': False, 'steerError': False, 'stopSteering': False}, 'logMonoTime': 103640364750, 'valid': True}
# 100%|██████████| 56301/56301 [00:02<00:00, 23939.20it/s]
# 100%|██████████| 58800/58800 [00:02<00:00, 24007.20it/s]
# 100%|██████████| 57125/57125 [00:02<00:00, 23065.00it/s]
# 100%|██████████| 56833/56833 [00:02<00:00, 26252.86it/s]
# 100%|██████████| 57432/57432 [00:02<00:00, 26819.68it/s]
# 100%|██████████| 57564/57564 [00:02<00:00, 26315.74it/s]
# 100%|██████████| 57312/57312 [00:02<00:00, 25342.74it/s]
# 100%|██████████| 57323/57323 [00:02<00:00, 26135.84it/s]
# 100%|██████████| 57300/57300 [00:02<00:00, 20732.06it/s]
# 100%|██████████| 57473/57473 [00:02<00:00, 19460.67it/s]
# 100%|██████████| 57192/57192 [00:02<00:00, 28592.33it/s]
#  82%|████████▏ | 47204/57431 [00:02<00:00, 17698.86it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-b075389931ef> in <module>
#      12         if e.which() not in ["carState", "controlsState", "sensorEvents"]:
#      13             continue
# ---> 14         parsed = e.to_dict()
#      15         for x in parsed:
#      16             if x =="carState":
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/capnp/lib/capnp.pyx in capnp.lib.capnp._DynamicStructReader.to_dict()
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/capnp/lib/capnp.pyx in capnp.lib.capnp._to_dict()
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/capnp/lib/capnp.pyx in capnp.lib.capnp._to_dict()
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/capnp/lib/capnp.pyx in capnp.lib.capnp._to_dict()
#
# KeyboardInterrupt:

# %%
acc = []
t_acc = []
alpha = []
t_alpha = []

t_sensor = []
t_CS = []

print(len(carState), len(controlsState), len(sensorEvents))
for i in (range(len(sensorEvents))):
    sensor = sensorEvents[i]
    time = sensor["logMonoTime"]
#     print(time)
    t_sensor.append(time)
    se = sensor["sensorEvents"] #Array of sensor outputs at some time
    for x in se:
        print(x)
        if "acceleration" in x:
            acc.append(x["acceleration"]["v"])
            t_acc.append(time)
        if "gyro" in x:
            alpha.append(x["gyro"]["v"])
            t_alpha.append(time)


for i in (range(len(carState))):
    CS = carState[i]
    time = CS["logMonoTime"]
    t_CS.append(time)

print(len(acc), len(alpha))
# Out:
# 'v': [-0.047637939453125, 0.029296875, 0.0073394775390625, -0.026947021484375, 0.0024566650390625, 0.0129852294921875], 'status': 0}, 'version': 104, 'sensor': 5, 'type': 16, 'timestamp': 192927227599, 'source': 'android', 'uncalibratedDEPRECATED': False}
# {'acceleration': {'v': [10.351470947265625, -0.6861114501953125, 0.4503936767578125], 'status': 3}, 'version': 104, 'sensor': 1, 'type': 1, 'timestamp': 192936627013, 'source': 'android', 'uncalibratedDEPRECATED': False}
# {'gyro': {'v': [-0.01824951171875, -0.0110015869140625, 0.0028839111328125], 'status': 3}, 'version': 104, 'sensor': 4, 'type': 4, 'timestamp': 192936627013, 'source': 'android', 'uncalibratedDEPRECATED': False}
# {'gyroUncalibrated': {'v': [-0.045196533203125, -0.008544921875, 0.015869140625, -0.026947021484375, 0.0024566650390625, 0.0129852294921875], 'status': 0}, 'version': 104, 'sensor': 5, 'type': 16, 'timestamp': 192936627013, 'source': 'android', 'uncalibratedDEPRECATED': False}
# {'magnetic': {'v': [-86.94000244140625, 99.420166015625, -23.82049560546875], 'status': 3}, 'version': 104, 'sensor': 2, 'type': 2, 'timestamp': 192941296203, 'source': 'android', 'uncalibratedDEPRECATED': False}
# {
 'source': 'android', 'uncalibratedDEPRECATED': False}
# {'gyroUncalibrated': {'v': [-0.047637939453125, 0.0366363525390625, 0.0, -0.026947021484375, 0.0024566650390625, 0.0129852294921875], 'status': 0}, 'version': 104, 'sensor': 5, 'type': 16, 'timestamp': 193162121398, 'source': 'android', 'uncalibratedDEPRECATED': False}
# {'acceleration': {'v': [10.20550537109375, -0.45880126953125, 0.6490020751953125], 'status': 3}, 'version': 104, 'sensor': 1, 'type': 1, 'timestamp': 193171520812, 'source': 'android', 'uncalibratedDEPRECATED': False}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-065f94baf1a2> in <module>
#      15     se = sensor["sensorEvents"] #Array of sensor outputs at some time
#      16     for x in se:
# ---> 17         print(x)
#      18         if "acceleration" in x:
#      19             acc.append(x["acceleration"]["v"])
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/ipykernel/iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     503                 )
#     504             data.group = group
# --> 505         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     506
#     507     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
print(len(t_sensor), len(t_CS))
t_CS+=[t_CS[-1]]*(len(t_sensor)-len(t_CS))
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams["figure.figsize"] = (20,12)

plt.plot(np.linspace(0, len(t_sensor), len(t_sensor)), t_sensor)
plt.plot(np.linspace(0, len(t_sensor), len(t_sensor)), t_CS)
# Out:
# 318158 210692

# %%
angle = []
desiredAngle = []
speed = []
torque_output = []
driver_torque = []

#Need sync
imu_v = []
imu_alpha = []

p_cars = 0
p_acc = 0
p_alpha = 0
for i in range(len(carState)-1):
    CS = carState[i]
    controls = controlsState[i]
    timeCS = CS["logMonoTime"]
#     print(timeCS, controls["logMonoTime"])
    while t_acc[p_acc] < timeCS:
        p_acc+=1
    while t_alpha[p_alpha] < timeCS:
        p_alpha+=1
    
    #CS, controls, sensors are matched
#     print(timeCS, controls["logMonoTime"], t_acc[p_acc], t_alpha[p_alpha])
    step = CS["carState"]
    angle.append(step["steeringAngleDeg"])
    speed.append(step["vEgo"])
    driver_torque.append(step["steeringTorque"])
    
    step = controls["controlsState"]
    desiredAngle.append(step["steeringAngleDesiredDeg"])
    torque_output.append(step["lateralControlState"]["pidState"]["output"])
    
    imu_v.append(acc[p_acc])
    imu_alpha.append(alpha[p_alpha])
#     print(step)
#     break

# %%
_, axs = plt.subplots(3)
time = len(carState)-1
axs[0].plot(np.linspace(0, time, time), speed)
axs[1].plot(np.linspace(0, time, time), angle)
axs[1].plot(np.linspace(0, time, time), desiredAngle)
axs[2].plot(np.linspace(0, time, time), [imu_v[i][0] for i in range(len(imu_v))])

# %%
goodOutputs = []
time = len(angle)
curr = []
for i in range(time):
    ok = True
    if speed[i]<20:
        ok = False
    if abs(driver_torque[i]) > 50:
        ok = False
    if ok:
        curr.append([i, angle[i], speed[i], torque_output[i], imu_v[i][0], imu_v[i][1], imu_v[i][2], imu_alpha[i][0], imu_alpha[i][1], imu_alpha[i][2]])
    if not ok:
        if len(curr) > 20 * 100:
            goodOutputs.append(curr)
            print(i-len(curr), i, len(curr)//100)
        curr = []
# Out:
# 10003 33212 232
# 33394 66532 331
# 66995 100021 330
# 100334 106892 65
# 106902 133590 266
# 163956 166867 29
# 168423 185196 167

# %%
import numpy as np
#Format:
# index, angle, speed, torque, IMU(speed_dot, angle_dot)*6
for i, output in enumerate(goodOutputs):
    np.savetxt(f"train_exports/{route_name}-{i}.csv", output, delimiter =" ", fmt ='% s')
